# %% [markdown]
# <a href="https://colab.research.google.com/github/sujal14shinde/assignments/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#assignment no.1
# Integer data type
a = 10
b = 25

print("Value of a:", a)
print("Value of b:", b)
print("Type of a:", type(a))


# Float data type
x = 10.5
y = 3.14

print("Value of x:", x)
print("Value of y:", y)
print("Type of x:", type(x))


# String data type
name = "Sujal"

print("Name:", name)
print("Type of name:", type(name))


# Boolean data type
is_student = True

print("Value:", is_student)
print("Type:", type(is_student))


# List data type
numbers = [10, 20, 30, 40]

print("List:", numbers)
print("First element:", numbers[0])
print("Type:", type(numbers))


# Tuple data type
colors = ("red", "green", "blue")

print("Tuple:", colors)
print("First element:", colors[0])
print("Type:", type(colors))


# Dictionary data type
student = {
    "name": "Sujal",
    "age": 18,
    "branch": "CSE"
}

print("Dictionary:", student)
print("Student name:", student["name"])
print("Type:", type(student))

# %%
# Assignment No: 2

# 1) WAP to add two numbers in Python
a = 18
b = 20
sum = a + b

print("First number:", a)
print("Second number:", b)
print("Sum =", sum)


# 2) WAP to declare variables and display their types
a = 10
b = 3.5
c = "Python"
d = True

print("Value of a:", a, "Type:", type(a))
print("Value of b:", b, "Type:", type(b))
print("Value of c:", c, "Type:", type(c))
print("Value of d:", d, "Type:", type(d))


# 3) WAP to demonstrate type casting in Python
a = 10
b = float(a)

print("Original value:", a)
print("After type casting to float:", b)
print("Type of b:", type(b))


# 4) WAP to demonstrate logical operators
a = 10
b = 5

print("a > 5 and b > 2:", a > 5 and b > 2)
print("a > 5 or b > 10:", a > 5 or b > 10)
print("not (a > 5):", not (a > 5))
