# %% [markdown]
# <a href="https://colab.research.google.com/github/sujal14shinde/assignments/blob/main/PercentageCalculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Student Percentage Calculator

name = input("Enter Student Name: ")

print("\nEnter marks out of 100")

sub1 = float(input("Subject 1: "))
sub2 = float(input("Subject 2: "))
sub3 = float(input("Subject 3: "))
sub4 = float(input("Subject 4: "))
sub5 = float(input("Subject 5: "))

# Total and Percentage
total = sub1 + sub2 + sub3 + sub4 + sub5
overall_percentage = (total / 500) * 100

# Pass/Fail Status
if sub1 >= 35 and sub2 >= 35 and sub3 >= 35 and sub4 >= 35 and sub5 >= 35:
    status = "PASS"
else:
    status = "FAIL"

print("\n----- STUDENT REPORT -----")
print("Student Name:", name)

print("\nMarks Obtained")
print("Subject 1:", sub1)
print("Subject 2:", sub2)
print("Subject 3:", sub3)
print("Subject 4:", sub4)
print("Subject 5:", sub5)

print("\nTotal Marks:", total, "/ 500")
print("Overall Percentage:", round(overall_percentage, 2), "%")
print("Result Status:", status)
# Out:
# Enter Student Name: sujal shinde
#
# Enter marks out of 100
# Subject 1: 80
# Subject 2: 75
# Subject 3: 90
# Subject 4: 65
# Subject 5: 65
#
# ----- STUDENT REPORT -----
# Student Name: sujal shinde
#
# Marks Obtained
# Subject 1: 80.0
# Subject 2: 75.0
# Subject 3: 90.0
# Subject 4: 65.0
# Subject 5: 65.0
#
# Total Marks: 375.0 / 500
# Overall Percentage: 75.0 %
# Result Status: PASS
